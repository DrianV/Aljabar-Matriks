# %%
import numpy as np

soal_np = np.array([[25], [2], [-3], [-23]])
print(soal_np)

print()

# transporse dari soal_np menjadi soal_t
soal_t = soal_np.T
print(f"Hasil Transpose dari soal_np adalah : {soal_t}")
# Out:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
#
# Hasil Transpose dari soal_np adalah : [[ 25   2  -3 -23]]
